# %%
import sys # Python 內建模組 Python 執行環境
from pathlib import Path # 檔案路徑

PROJECT_ROOT = Path.cwd().parent # cwd()找到工作目錄 .parent 往上一層資料夾。
sys.path.append(str(PROJECT_ROOT)) # Python 在 import 模組時，會去哪裡找檔案

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: c:\AI_class\Kai_Smart E-Commerce Recommendation System

# %%
import pymysql
import pandas as pd
from scripts.db_config import DB_CONFIG

conn = pymysql.connect(**DB_CONFIG)

query = """
SELECT *
FROM orders
LIMIT 5;
"""

df = pd.read_sql(query, conn)

conn.close()

df
# Out:
# C:\Users\KAI\AppData\Local\Temp\ipykernel_11884\900671989.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# ...
